# %% [markdown]
# <a href="https://colab.research.google.com/github/suyash091/kidney-failure/blob/master/kidney%20failure.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**IMPORTING THE DATASET**

# %%
import os
os.environ['KAGGLE_USERNAME'] = "suyash091"
os.environ['KAGGLE_KEY'] = "9775b0a6da90b12a0c284d71e498de43"
#!kaggle datasets download -d sulianova/cardiovascular-disease-dataset #CardioVascular
# !kaggle datasets download -d akshayksingh/kidney-disease-dataset
# Out:
# Downloading kidney-disease-dataset.zip to /content
#   0% 0.00/9.51k [00:00<?, ?B/s]
# 100% 9.51k/9.51k [00:00<00:00, 15.9MB/s]

# %% [markdown]
# **Extracting zipfile**

# %%
#!unzip -q '/content/cardiovascular-disease-dataset.zip' 
# !unzip -q '/content/kidney-disease-dataset.zip'

# %%
import pandas as pd

# %% [markdown]
# **Data Preprocessing**

# %%
#Fixing structure
# Read in the file
with open('/content/ALF_Data.csv', 'r') as file :
  filedata = file.read()

# Replace the target string
filedata = filedata.replace(';', ',')

# Write the file out again
with open('/content/ALF_Data.csv', 'w') as file:
  file.write(filedata)

# %%
#Load Data
cvd=pd.read_csv('/content/kidney_disease.csv').dropna()#.apply(lambda x: x/x.max(), axis=0)
# Import label encoder 


cvd.head(20)
# Out:
#       id   age     bp     sg   al   su  ...   dm  cad appet   pe  ane  classification
# 3      3  48.0   70.0  1.005  4.0  0.0  ...   no   no  poor  yes  yes             ckd
# 9      9  53.0   90.0  1.020  2.0  0.0  ...  yes   no  poor   no  yes             ckd
# 11    11  63.0   70.0  1.010  3.0  0.0  ...  yes   no  poor  yes   no             ckd
# 14    14  68.0   80.0  1.010  3.0  2.0  ...  yes  yes  poor  yes   no             ckd
# 20    20  61.0   80.0  1.015  2.0  0.0  ...  yes  yes  poor  yes  yes             ckd
# 22    22  48.0   80.0  1.025  4.0  0.0  ...   no   no  good   no  yes             ckd
# 27    27  69.0   70.0  1.010  3.0  4.0  ...  yes  yes  good  yes   no             ckd
# 48    48  73.0   70.0  1.005  0.0  0.0  ...  yes   no  good  yes   no             ckd
# 58    58  73.0   80.0  1.020  2.0  0.0  ...  yes  yes  good   no   no             ckd
# 71    71  46.0   60.0  1.010  1.0  0.0  ...  yes   no  good   no   no             ckd
# 74    74  56.0   90.0  1.015  2.0  0.0  ...   no   no  good   no   no             ckd
# 76    76  48.0   80.0  1.005  4.0  0.0  ...  yes   no  good  yes   no             ckd
# 84    84  59.0   70.0  1.010  3.0  0.0  ...   no   no  poor  yes  yes             ckd
# 90    90  63.0  100.0  1.010  2.0  2.0  ...   no  yes  good   no   no             ckd
# 91    91  56.0   70.0  1.015  4.0  1.0  ...   no   no  good   no   no             ckd
# 92    92  71.0   70.0  1.010  3.0  0.0  ...  yes  yes  good   no   no             ckd
# 93    93  73.0  100.0  1.010  3.0  2.0  ...  yes  yes  poor   no   no             ckd
# 127  127  71.0   60.0  1.015  4.0  0.0  ...  yes   no  poor  yes   no             ckd
# 128  128  52.0   90.0  1.015  4.0  3.0  ...  yes   no  good   no  yes             ckd
# 130  130  50.0   90.0  1.010  2.0  0.0  ...   no   no  poor  yes  yes             ckd
#
# [20 rows x 26 columns]

# %%
from sklearn import preprocessing 
  
# label_encoder object knows how to understand word labels. 
label_encoder = preprocessing.LabelEncoder() 

# apply "le.fit_transform"
cvd = cvd.apply(label_encoder.fit_transform)

# %%
cvd.head(50)
# Out:
#      id  age  bp  sg  al  su  rbc  ...  htn  dm  cad  appet  pe  ane  classification
# 3     0   29   2   0   4   0    1  ...    1   0    0      1   1    1               0
# 9     1   34   4   3   2   0    0  ...    1   1    0      1   0    1               0
# 11    2   43   2   1   3   0    0  ...    1   1    0      1   1    0               0
# 14    3   47   3   1   3   2    1  ...    1   1    1      1   1    0               0
# 20    4   41   3   2   2   0    0  ...    1   1    1      1   1    1               0
# 22    5   29   3   4   4   0    1  ...    1   0    0      0   0    1               0
# 27    6   48   2   1   3   4    1  ...    1   1    1      0   1    0               0
# 48    7   52   2   0   0   0    1  ...    1   1    0      0   1    0               0
# 58    8   52   3   3   2   0    0  ...    1   1    1      0   0    0               0
# 71    9   27   1   1   1   0    1  ...    1   1    0      0   0    0               0
# 74   10   36   4   2   2   0    0  ...    1   0    0      0   0    0               0
# 76   11   29   3   0   4   0    0  ...    0   1    0      0   1    0               0
# 84   12   39   2   1   3   0    1  ...    1   0    0      1   1    1               0
# 90   13   43   5   1   2   2    1  ...    1   0    1      0   0    0               0
# 91   14   36   2   2   4   1    0  ...    0   0    0      0   0    0               0
# 92   15   50   2   1   3   0    1  ...    1   1    1      0   0    0               0
# 93   16   52   5   1   3   2    0  ...    1   1    1      1   0    0               0
# 127  17   50   1   2   4   0    1  ...    1   1    0      1   1    0               0
# 128  18   33   4   2   4   3    1  ...    1   1    0      0   0    1               0
# 130  19   31   4   1   2   0    1  ...    0   0    0      1   1    1               0
# 133  20   49   5   2   4   0    1  ...    1   0    0      0   0    0               0
# 144  21   40   4   1   2   0    0  ...    0   0    0      0   0    0               0
# 147  22   40   1   1   3   1    1  ...    1   0    0      1   0    1               0
# 153  23   35   4   1   2   1    0  ...    1   1    0      1   1    1               0
# 157  24   42   2   4   3   0    1  ...    1   1    0      0   0    0               0
# 159  25   39   3   1   1   0    0  ...    0   1    0      1   0    0               0
# 171  26   57   2   3   3   0    1  ...    1   0    0      1   0    1               0
# 176  27    5   4   1   4   0    1  ...    0   0    0      0   0    1               0
# 181  28   26   2   4   2   0    1  ...    0   0    0      0   0    0               0
# 189  29   44   1   1   4   1    0  ...    1   1    0      1   1    0               0
# 190  30    0   1   1   4   0    0  ...    0   0    0      1   0    0               0
# 196  31   30   5   1   3   0    0  ...    1   1    0      1   1    1               0
# 198  32   39   5   3   4   2    1  ...    1   1    0      1   1    0               0
# 210  33   39   5   2   4   2    1  ...    1   1    1      0   0    1               0
# 212  34   21   2   2   3   4    1  ...    1   1    0      1   1    0               0
# 213  35   35   3   1   3   1    1  ...    1   1    0      0   1    0               0
# 225  36   40   4   1   3   5    0  ...    1   1    0      0   0    0               0
# 226  37   44   5   2   4   2    0  ...    1   1    0      0   1    0               0
# 229  38   39   0   1   3   0    1  ...    0   1    0      0   1    0               0
# 242  39   48   2   1   4   3    1  ...    1   1    1      0   1    1               0
# 246  40   29   6   2   3   0    0  ...    1   0    1      0   0    1               0
# 248  41   39   2   1   1   3    0  ...    1   1    1      0   0    0               0
# 249  42   36   4   1   4   1    1  ...    1   1    0      1   1    1               0
# 250  43   21   3   4   0   0    1  ...    0   0    0      0   0    0               1
# 251  44    7   3   4   0   0    1  ...    0   0    0      0   0    0               1
# 252  45   26   3   4   0   0    1  ...    0   0    0      0   0    0               1
# 253  46   37   3   4   0   0    1  ...    0   0    0      0   0    0               1
# 254  47   32   1   4   0   0    1  ...    0   0    0      0   0    0               1
# 255  48   15   3   4   0   0    1  ...    0   0    0      0   0    0               1
# 256  49   40   3   4   0   0    1  ...    0   0    0      0   0    0               1
#
# [50 rows x 26 columns]

# %%
#For K-fold cross validation
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(n_estimators=100)
outcome_var = ['classification']
predictor_var = list('age	bp	sg	al	su	rbc	pc	pcc	ba	bgr	bu	sc	sod	pot	hemo	pcv	wc	rc	htn	dm	cad	appet	pe	ane'.split())

# %%
#Import models from scikit learn module:
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import KFold
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn import metrics
import numpy as np

#Generic function for making a classification model and accessing performance:
def classification_model(model, data, predictors, outcome):
  model.fit(data[predictors],data[outcome].values.ravel())
  
  predictions = model.predict(data[predictors])
  
  accuracy = metrics.accuracy_score(predictions,data[outcome])
  print('Accuracy : %s' % '{0:.3%}'.format(accuracy))

  kf = KFold(n_splits=5)
  error = []
  for train, test in kf.split(data[predictors]):
    train_predictors = (data[predictors].iloc[train,:])
    
    train_target = data[outcome].iloc[train]
    
    model.fit(train_predictors, train_target.values.ravel())
    
    error.append(model.score(data[predictors].iloc[test,:], data[outcome].iloc[test]))
 
  print('Cross-Validation Score : %s' % '{0:.3%}'.format(np.mean(error)))

  return model.fit(data[predictors],data[outcome].values.ravel())

# %%
#outcome_var = ['winner']
#predictor_var = ['team1', 'team2', 'venue', 'toss_winner','city','toss_decision']
history=classification_model(model, cvd,predictor_var,outcome_var)
# Out:
# Accuracy : 100.000%
# Cross-Validation Score : 99.375%

# %%
#inp=list(map(str,[18393,	2,	168,	62.0,	110,	80,	1,	1,	0,	0,	1]))
inp=list(map(str,'63	1	3	145	233	1	0	150	0	2.3	0	0	1'.split()))
inp = np.array(inp).reshape((1, -1))
output=model.predict(inp)

# %%
print(output)
# Out:
# [1]

# %%
from sklearn.externals import joblib
joblib.dump(model, 'acuteliverfailure.pkl')
# Out:
# ['acuteliverfailure.pkl']

# %%
import pickle
filename = 'Kidneyfail.sav'
pickle.dump(model, open(filename, 'wb'))

# %%
loaded_model = pickle.load(open(filename, 'rb'))

# %%
from sklearn.externals import joblib
import pandas as pd
import numpy as np
#clf = joblib.load('Cardiomodel.pkl')
#inp=list(map(str,[18393,	2,	168,	62.0,	110,	80,	1,	1,	0,	0,	1]))
inp=list(map(str,'40	3	4	0	0	1	1	0	0	49	0	1	23	21	46	19	6	25	0	0	0	0	0	0'.split()))
inp = np.array(inp).reshape((1, -1))
result = loaded_model.predict(inp)

# %%
print(result)
# Out:
# [1]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !mv '/content/Kidneyfail.sav' '/content/drive/My Drive/rackathon/Kidneyfail.sav'
